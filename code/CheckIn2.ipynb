# %% [markdown]
# # Capstone Check In Two
#
# ## Problem Statement
#
# I will be using [county-level data on education, unemployment, poverty, and population from the US Department of Agriculture's Economic Research Service](https://www.ers.usda.gov/data-products/county-level-data-sets/download-data/) to examine the correlations between different statistics and to look for regional trends. In particular, I intend to build a logistic regression predicting poverty based on the other available features, do clustering to see if regional clusters are apparent, and if clustering can be done well, run logistic regressions again for each cluster to see how the coefficients of different factors vary region to region. In a sense, my metric for success will be the accuracy of the logistic regression models and the silhouette score of the clusters, but if I fail to build a highly predictive model it may ultimately tell me as much as getting strong, expected correlations.

# %%
import pandas as pd

# %%
# Figured out that I need to change the encoding to read in these files
ed_data = pd.read_csv("./Education.csv", encoding='latin-1')

# %%
ed_data.head()
# Out:
#    FIPS Code State       Area name  2003 Rural-urban Continuum Code  \
# 0          0    US   United States                              NaN
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga County                              2.0
# 3       1003    AL  Baldwin County                              4.0
# 4       1005    AL  Barbour County                              6.0
#
#    2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    2013 Urban Influence Code Less than a high school diploma, 1970  \
# 0                        NaN                            52,373,312
# ...

# %%
ed_data.shape
# Out:
# (3283, 47)

# %%
ed_data.describe()
# Out:
#           FIPS Code  2003 Rural-urban Continuum Code  \
# count   3283.000000                      3221.000000
# mean   31308.242766                         5.057125
# std    16343.477485                         2.701247
# min        0.000000                         1.000000
# 25%    19016.000000                         3.000000
# 50%    30017.000000                         6.000000
# 75%    46100.000000                         7.000000
# max    72153.000000                         9.000000
#
#        2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# count                3221.000000                      3221.000000
# mean                    5.371624                         4.936976
# std                     3.483776                         2.724413
# min                     1.000000                         1.000000
# 25%                     2.000000                         2.000000
# 50%                     5.000000                         6.000000
# ...
